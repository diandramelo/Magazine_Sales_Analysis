# %% [markdown]
# # 0. IMPORTS

# %% [markdown]
# ## 0.1. Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## 0.2. Datasets

# %% [markdown]
# ### 0.2.1. Transactions

# %%
df_transactions = pd.read_csv('data/transactions.csv')

# %%
df_transactions.head()
# Out:
#   id_prod                        date session_id client_id
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1   2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2   1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3  0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242

# %%
print('Number of rows: {}'.format(df_transactions.shape[0]))
print('Number of columns: {}'.format(df_transactions.shape[1]))
# Out:
# Number of rows: 337016
# Number of columns: 4

# %% [markdown]
# ### 0.2.2. Customers

# %%
df_customers = pd.read_csv('data/customers.csv')

# %%
df_customers.head()
# Out:
#   client_id sex  birth
# 0    c_4410   f   1967
# 1    c_7839   f   1975
# 2    c_1699   f   1984
# 3    c_5961   f   1962
# 4    c_5320   m   1943

# %%
print('Number of rows: {}'.format(df_customers.shape[0]))
print('Number of columns: {}'.format(df_customers.shape[1]))
# Out:
# Number of rows: 8623
# Number of columns: 3

# %% [markdown]
# ### 0.2.3. Products

# %%
df_products = pd.read_csv('data/products.csv')

# %%
df_products.head()
# Out:
#   id_prod  price  categ
# 0  0_1421  19.99      0
# 1  0_1368   5.13      0
# 2   0_731  17.99      0
# 3   1_587   4.99      1
# 4  0_1507   3.99      0

# %%
print('Number of rows: {}'.format(df_products.shape[0]))
print('Number of columns: {}'.format(df_products.shape[1]))
# Out:
# Number of rows: 3287
# Number of columns: 3

# %% [markdown]
# ## 0.3. Graph visualization

# %%
from IPython.core.display import HTML

def jupyter_settings():
   # %matplotlib inline
   # %pylab inline
   plt.style.use( 'bmh' )
   plt.rcParams['figure.figsize'] = [18, 8]
   plt.rcParams['font.size'] = 20
   display( HTML( '<style>.container { width:100% !important; }</style>') )
   pd.options.display.max_columns = None
   pd.options.display.max_rows = None
   pd.set_option( 'display.expand_frame_repr', False )
   sns.set()
    
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # 1. DATA CLEANING

# %% [markdown]
# ## 1.1. Creating main DataFrame

# %%
df1 = df_transactions.merge(df_customers, how = 'left', on = 'client_id')
df1 = df1.merge(df_products, how = 'left', on = 'id_prod')

#reordering columns
columns_ordered = ['id_prod', 'price', 'categ', 'date', 'client_id', 'sex', 'birth']
df1 = df1[columns_ordered]

# %%
df1.head()
# Out:
#   id_prod  price  categ                        date client_id sex  birth
# 0  0_1483   4.99    0.0  2021-04-10 18:37:28.723910    c_4450   f   1977
# 1   2_226  65.75    2.0  2022-02-03 01:55:53.276402     c_277   f   2000
# 2   1_374  10.71    1.0  2021-09-23 15:13:46.938559    c_4270   f   1979
# 3  0_2186   4.20    0.0  2021-10-17 03:27:18.783634    c_4597   m   1963
# 4  0_1351   8.99    0.0  2021-07-17 20:34:25.800563    c_1242   f   1980

# %% [markdown]
# ## 1.2. Data Dimensions

# %%
print('Number of rows: {}'.format(df1.shape[0]))
print('Number of columns: {}'.format(df1.shape[1]))
# Out:
# Number of rows: 337016
# Number of columns: 7

# %% [markdown]
# ## 1.3. Check NAs

# %%
df1.isna().sum()
# Out:
# id_prod        0
# price        103
# categ        103
# date           0
# client_id      0
# sex            0
# birth          0
# dtype: int64

# %%
# check if NA values for `price` and `categ` are in the same rows
df_na = df1[df1['price'].isna() | df1['categ'].isna()]
df_na.shape[0]
# Out:
# 103

# %%
# check which products have NA values
df_na['id_prod'].unique()
# Out:
# array(['0_2245'], dtype=object)

# %%
df_na.head()
# Out:
#       id_prod  price  categ                        date client_id sex  birth
# 6235   0_2245    NaN    NaN  2021-06-17 03:03:12.668129    c_1533   m   1972
# 10802  0_2245    NaN    NaN  2021-06-16 05:53:01.627491    c_7954   m   1973
# 14051  0_2245    NaN    NaN  2021-11-24 17:35:59.911427    c_5120   f   1975
# 17486  0_2245    NaN    NaN  2022-02-28 18:08:49.875709    c_4964   f   1982
# 21078  0_2245    NaN    NaN  2021-03-01 00:09:29.301897     c_580   m   1988

# %% [markdown]
# ### 1.3.1. Fillout NAs
# Empty features: `price` and `categ` for `id_prod` == '0_2245'

# %%
# does the dataframe possess a row with price and category for this product?
# answer: no, because the same number of rows is given for the NA dataframe and the product lines
df1[df1['id_prod'] == '0_2245'].shape[0]
# Out:
# 103

# %%
print('Average year birth of clients: {}'.format(df1[df1['id_prod'] == '0_2245']['birth'].mean().round()))
print('Predominant sex of clients: {}'.format(df1[df1['id_prod'] == '0_2245']['sex'].mode()[0]))
# Out:
# Average year birth of clients: 1977.0
# Predominant sex of clients: f

# %%
df_f_1977_avg = df1[(df1['birth'] == 1977) & (df1['sex'] == 'f')]
print('Average price of products sold for female clients born in 1977: $ {}'.format(df_f_1977_avg['price'].mean().round(2)))
print('Predominant category of products sold for female clients born in 1977: {}'.format(df_f_1977_avg['categ'].mode()[0]))
# Out:
# Average price of products sold for female clients born in 1977: $ 12.99
# Predominant category of products sold for female clients born in 1977: 0.0

# %%
# Attributing average price and main category for the product '0_2245':
# df1['price']
values = {'price': 12.99, 'categ': '0'}

df1 = df1.fillna(value = values)

# %% [markdown]
# ## 1.4. Check duplicates

# %%
print('Duplicated lines: {}'.format(df1.duplicated().sum()))
# Out:
# Duplicated lines: 126

# %%
df1[df1.duplicated() == True]
# Out:
#        id_prod  price  categ                             date client_id sex  birth
# 34387      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237443      ct_0   f   2001
# 54813      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237412      ct_1   m   2001
# 57261      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237439      ct_1   m   2001
# 58802      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237429      ct_0   f   2001
# 60170      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237446      ct_0   f   2001
# 62365      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237412      ct_1   m   2001
# 71097      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237446      ct_0   f   2001
# 72405      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237424      ct_1   m   2001
# 75176      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237443      ct_1   m   2001
# 76735      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237442      ct_0   f   2001
# 80189      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237414      ct_1   m   2001
# 81712      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237443      ct_1   m   2001
# 88935      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237446      ct_0   f   2001
# 90375      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237430      ct_1   m   2001
# 95214      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237436      ct_0   f   2001
# 95537      T_0   -1.0    0.0  test_2021-03-01 02:30:02.237413      ct_0   f   2001
# 100544     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237413      ct_0   f   2001
# 100706     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237418      ct_1   m   2001
# 104078     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237412      ct_1   m   2001
# 107589     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237427      ct_1   m   2001
# 109107     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237413      ct_0   f   2001
# 111471     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237429      ct_1   m   2001
# 114308     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237432      ct_1   m   2001
# 120460     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237425      ct_1   m   2001
# 122934     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237414      ct_1   m   2001
# 124247     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237435      ct_0   f   2001
# 126388     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237418      ct_1   m   2001
# 126679     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237435      ct_0   f   2001
# 132564     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237413      ct_1   m   2001
# 134120     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237424      ct_0   f   2001
# 137561     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237426      ct_1   m   2001
# 138566     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237424      ct_1   m   2001
# 141623     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237413      ct_0   f   2001
# 141628     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237442      ct_0   f   2001
# 141636     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237443      ct_1   m   2001
# 141964     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237414      ct_1   m   2001
# 142799     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237428      ct_0   f   2001
# 144975     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237447      ct_1   m   2001
# 154141     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237419      ct_0   f   2001
# 156799     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237433      ct_1   m   2001
# 163897     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237440      ct_1   m   2001
# 168992     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237437      ct_0   f   2001
# 171058     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237441      ct_0   f   2001
# 175243     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237427      ct_1   m   2001
# 178337     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237414      ct_0   f   2001
# 180167     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237432      ct_0   f   2001
# 180530     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237430      ct_0   f   2001
# 187732     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237437      ct_0   f   2001
# 190020     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237413      ct_1   m   2001
# 193446     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237413      ct_1   m   2001
# 195764     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237441      ct_0   f   2001
# 195809     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237427      ct_0   f   2001
# 195812     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237426      ct_0   f   2001
# 201477     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237428      ct_0   f   2001
# 203237     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237434      ct_1   m   2001
# 203418     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237449      ct_0   f   2001
# 206261     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237419      ct_0   f   2001
# 207130     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237446      ct_0   f   2001
# 209223     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237443      ct_0   f   2001
# 210294     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237432      ct_0   f   2001
# 215800     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237436      ct_0   f   2001
# 218660     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237443      ct_1   m   2001
# 220105     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237444      ct_1   m   2001
# 221370     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237419      ct_1   m   2001
# 221500     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237417      ct_0   f   2001
# 221958     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237428      ct_0   f   2001
# 225450     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237426      ct_0   f   2001
# 225702     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237445      ct_1   m   2001
# 227097     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237415      ct_0   f   2001
# 230316     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237430      ct_1   m   2001
# 232582     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237417      ct_0   f   2001
# 233371     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237430      ct_1   m   2001
# 234639     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237416      ct_0   f   2001
# 237654     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237435      ct_1   m   2001
# 242788     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237420      ct_0   f   2001
# 246350     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237444      ct_0   f   2001
# 246514     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237432      ct_1   m   2001
# 247762     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237416      ct_0   f   2001
# 248762     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237444      ct_0   f   2001
# 250067     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237444      ct_1   m   2001
# 250656     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237431      ct_1   m   2001
# 251993     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237435      ct_0   f   2001
# 252328     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237440      ct_0   f   2001
# 252354     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237440      ct_1   m   2001
# 255007     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237414      ct_1   m   2001
# 256011     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237420      ct_1   m   2001
# 256297     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237423      ct_0   f   2001
# 259192     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237444      ct_0   f   2001
# 265206     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237427      ct_0   f   2001
# 267387     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237428      ct_0   f   2001
# 267907     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237413      ct_0   f   2001
# 268100     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237428      ct_0   f   2001
# 268271     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237437      ct_1   m   2001
# 270923     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237427      ct_1   m   2001
# 271029     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237438      ct_1   m   2001
# 271894     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237444      ct_1   m   2001
# 275002     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237413      ct_0   f   2001
# 277079     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237428      ct_1   m   2001
# 280690     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237413      ct_0   f   2001
# 282567     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237413      ct_0   f   2001
# 283473     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237427      ct_0   f   2001
# 286622     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237426      ct_1   m   2001
# 288118     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237447      ct_1   m   2001
# 292405     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237415      ct_1   m   2001
# 295549     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237441      ct_0   f   2001
# 296251     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237414      ct_0   f   2001
# 297294     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237420      ct_0   f   2001
# 299737     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237419      ct_0   f   2001
# 301070     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237442      ct_0   f   2001
# 302858     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237432      ct_0   f   2001
# 310140     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237412      ct_1   m   2001
# 311263     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237438      ct_0   f   2001
# 320121     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237440      ct_1   m   2001
# 323692     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237429      ct_0   f   2001
# 326425     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237446      ct_0   f   2001
# 327926     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237434      ct_1   m   2001
# 328925     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237437      ct_0   f   2001
# 329634     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237438      ct_0   f   2001
# 330454     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237436      ct_0   f   2001
# 331787     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237416      ct_1   m   2001
# 332163     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237425      ct_1   m   2001
# 332594     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237445      ct_0   f   2001
# 332705     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237423      ct_1   m   2001
# 332730     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237421      ct_1   m   2001
# 333442     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237431      ct_1   m   2001
# 335279     T_0   -1.0    0.0  test_2021-03-01 02:30:02.237430      ct_0   f   2001

# %% [markdown]
# ### 1.4.1. Dropping duplicates

# %%
df1 = df1.drop_duplicates()

# %% [markdown]
# ## 1.5. Odd values

# %%
# there are some test inputs that do not give any relevant information to the study case:
df1.sort_values(by = 'price').head()
# Out:
#        id_prod  price categ                             date client_id sex  birth
# 2365       T_0   -1.0     0  test_2021-03-01 02:30:02.237446      ct_1   m   2001
# 109598     T_0   -1.0     0  test_2021-03-01 02:30:02.237437      ct_1   m   2001
# 137506     T_0   -1.0     0  test_2021-03-01 02:30:02.237432      ct_0   f   2001
# 293107     T_0   -1.0     0  test_2021-03-01 02:30:02.237421      ct_0   f   2001
# 59043      T_0   -1.0     0  test_2021-03-01 02:30:02.237413      ct_0   f   2001

# %%
df1 = df1[df1['price'] > 0] # keep only product values above $0

# %%
print('Quantity of lines after dropping duplicates and odd values: {}'.format(df1.shape[0]))
print('Quantity of lines removed: {}'.format(337016 - df1.shape[0]))
# Out:
# Quantity of lines after dropping duplicates and odd values: 336816
# Quantity of lines removed: 200

# %% [markdown]
# ## 1.6. Data Types

# %%
df1.dtypes
# Out:
# id_prod       object
# price        float64
# categ         object
# date          object
# client_id     object
# sex           object
# birth          int64
# dtype: object

# %% [markdown]
# ### 1.6.1. Changing Data Types

# %%
df1['categ'] = np.where(df1['categ'].isnull(), df1['categ'], df1['categ'].astype(str).str[0])

# %%
df1['date'] = pd.to_datetime(df1['date'], format = '%Y-%m-%d')

# %% [markdown]
# ## 1.7. Feature Engineering

# %%
df1.head()
# Out:
#   id_prod  price categ                       date client_id sex  birth  age  year  month  day  hour period_of_day
# 0  0_1483   4.99     0 2021-04-10 18:37:28.723910    c_4450   f   1977   43  2021      4   10    18         night
# 1   2_226  65.75     2 2022-02-03 01:55:53.276402     c_277   f   2000   20  2022      2    3     1  morning_dawn
# 2   1_374  10.71     1 2021-09-23 15:13:46.938559    c_4270   f   1979   41  2021      9   23    15     afternoon
# 3  0_2186   4.20     0 2021-10-17 03:27:18.783634    c_4597   m   1963   57  2021     10   17     3  morning_dawn
# 4  0_1351   8.99     0 2021-07-17 20:34:25.800563    c_1242   f   1980   40  2021      7   17    20         night

# %%
# Create variables:
## Age
df1['age'] = df1['birth'].apply(lambda x: 2020 - x)

## Year of purchase
df1['year'] = df1['date'].dt.year

## Month of purchase
df1['month'] = df1['date'].dt.month

## Day of purchase
df1['day'] = df1['date'].dt.day

## Hour of purchase
df1['hour'] = df1['date'].dt.hour

## Time of day (morning / afternoon / evening)
df1['period_of_day'] = df1['hour'].apply(lambda x: 'morning_dawn' if x < 6
                                              else 'morning' if x < 12
                                              else 'afternoon' if x < 18
                                              else 'night')

# %% [markdown]
# ## 1.8. Creating Dataset for another script

# %%
df1.to_csv('data/dataframe_for_analysis.csv', index = False)
